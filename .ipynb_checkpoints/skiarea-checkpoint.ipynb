# %%
import os
import requests
import re
import csv
import json
from geojson import Feature, FeatureCollection, Point

# %%
skiareas = []
with open("rawskidata.txt") as f:
    for line in f:
        match = re.search('<li>', line)
        if(match):
            match = re.search('href\S+', line)
            if(match):
                skiareas.append(match.group(0)[6:-1])

# %%
skiareas[0][6:]
# Out:
# 'Mohawk_Mountain_Ski_Area'

# %%
for num in range(len(skiareas)):
    URL = 'https://en.wikipedia.org' + skiareas[num]
    data = requests.get(URL, stream=True)
    #     college_sb_data.append(pd.Series(name=str(yr)))
    for line in data.iter_lines():
        match = re.search('Vertical</th><td>(.[\d,]*)', str(line))
        if(match):
            if(len(match.group(1)) > 1):
                vert_value = match.group(1).replace(',', '')
                print(vert_value)
# Out:
# 650
# 425
# 550
# 625
# 1380
# 845
# 240
# 2000
# 1300
# 2820
# 465
# 309
# 750
# 1000
# 1150
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-51dec4564364> in <module>
#       1 for num in range(len(skiareas)):
#       2     URL = 'https://en.wikipedia.org' + skiareas[num]
# ----> 3     data = requests.get(URL, stream=True)
#       4     #     college_sb_data.append(pd.Series(name=str(yr)))
#       5     for line in data.iter_lines():
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     595
#     596             # Make the request on the httplib connection object.
# --> 597             httplib_response = self._make_request(conn, method, url,
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
for num in range(len(skiareas)):
    viewcount = 0
    URL = 'https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/en.wikipedia/all-access/all-agents/' + skiareas[num][6:] + '/monthly/2020010100/2020123100'
    data = requests.get(url = URL, headers = headers)
    data_json = data.json()
    #     college_sb_data.append(pd.Series(name=str(yr)))
    for month in data_json['items']:
        viewcount += month['views']
    print(viewcount)
    break
# Out:
# 1009
# 1948
# 2386
# 2724
# 3250
# 3565
# 3962
# 4438
# 4871
# 5358
# 5887
# 7258
# 7258

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
ski_areas_formatted = []
for num in range(len(skiareas)):
    URL = 'https://en.wikipedia.org' + skiareas[num]
    data = requests.get(URL, stream=True)
    name = None
    coords = None
    vert = None
    viewcount = 0
    for line in data.iter_lines():
        
        if line:
            line = str(line)[2:]
            match = re.search('<title>', line)
            if(match):
                name = line[7:-21]
            match = re.search('for this location">\d.+', line)
            if(match):
                coords = (match.group(0)[19:45]).split('\\xc2\\xb0N ')
            match = re.search('Vertical</th><td>(.[^<]*)', str(line))
            match = re.search('Vertical</th><td>(.[\d,]*)', str(line))
            if(match):
                if(len(match.group(1)) > 1):
                    vert = match.group(1).replace(',', '')
    
    URL = 'https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/en.wikipedia/all-access/all-agents/' + skiareas[num][6:] + '/monthly/2020010100/2020123100'
    data = requests.get(url = URL, headers = headers)
    if data.status_code == 200:
        data_json = data.json()
        for month in data_json['items']:
            viewcount += month['views']
        
    if name and coords and vert:
        ski_areas_formatted.append({'name': name, 'lat': coords[0], 'lng': coords[1], 'pageviews': viewcount, 'vert': vert})
        name = None
        coords = None
        vert = None
        viewcount = 0
    elif name and coords:
        ski_areas_formatted.append({'name': name, 'lat': coords[0], 'lng': coords[1], 'pageviews': viewcount})
        name = None
        coords = None
        viewcount = 0
    
            
    print('on', num, 'out of,', len(skiareas))
    print(ski_areas_formatted[len(ski_areas_formatted)-1])
# Out:
# on 0 out of, 453
# {'name': 'Mohawk Mountain Ski Area', 'lat': '41.83675', 'lng': '73.31342', 'vert': '650'}
# on 1 out of, 453
# {'name': 'Mount Southington', 'lat': '41.58235', 'lng': '72.92587', 'vert': '425'}
# on 2 out of, 453
# {'name': 'Powder Ridge Ski Area', 'lat': '41.502006', 'lng': '72.7371', 'vert': '550'}
# on 3 out of, 453
# {'name': 'Ski Sundown', 'lat': '41.88407', 'lng': '72.94523', 'vert': '625'}
# on 4 out of, 453
# {'name': 'Baker Mountain (ski area)', 'lat': '45.08472', 'lng': '69.90556'}
# on 5 out of, 453
# {'name': 'Big Rock (ski resort)', 'lat': '46.52222', 'lng': '67.82778'}
# on 6 out of, 453
# {'name': 'Big Squaw Mountain Resort', 'lat': '45.50417', 'lng': '69.70556'}
# on 7 out of, 453
# {'name': 'Black Mountain of Maine', 'lat': '44.58000', 'lng': '70.61750', 'vert': '1380'}
# on 8 out of, 453
# {'name': 'Camden Snow Bowl', 'lat': '44.217216', 'lng': '69.1346', 'vert': '845'}
# on 9 out of, 453
# {'name': 'Eaton Mountain', 'lat': '44.76806', 'lng': '69.61944'}
# on 10 out of, 453
# {'name': 'Eaton Mountain', 'lat': '44.76806', 'lng': '69.61944'}
# on 11 out of, 453
# {'name': 'Lonesome Pine Trails', 'lat': '47.23278', 'lng': '68.59306'}
# on 12 out of, 453
# {'name': 'Lost Valley Ski Area', 'lat': '44.136', 'lng': '70.281\\xc2', 'vert': '240'}
# on 13 out of, 453
# {'name': 'Ski Mount Abram', 'lat': '44.37917', 'lng': '70.70694'}
# on 14 out of, 453
# {'name': 'Ski Mount Abram', 'lat': '44.37917', 'lng': '70.70694'}
# on 15 out of, 453
# {'name': 'Powderhouse Hill (ski area)', 'lat': '43.23694', 'lng': '70.80222'}
# on 16 out of, 453
# {'name': 'Powderhouse Hill (ski area)', 'lat': '43.23694', 'lng': '70.80222'}
# on 17 out of, 453
# {'name': 'Saddleback Maine (ski resort)', 'lat': '44.93667', 'lng': '70.50306', 'vert': '2000'}
# on 18 out of, 453
# {'name': 'Shawnee Peak Ski Area', 'lat': '44.05833', 'lng': '70.81528', 'vert': '1300'}
# on 19 out of, 453
# {'name': 'Sugarloaf (ski resort)', 'lat': '45.03139', 'lng': '70.31306', 'vert': '2820'}
# on 20 out of, 453
# {'name': 'Sunday River (ski resort)', 'lat': '44.46944', 'lng': '70.86111'}
# on 21 out of, 453
# {'name': 'Titcomb Mountain', 'lat': '44.65000', 'lng': '70.17083'}
# on 22 out of, 453
# {'name': 'Berkshire East Ski Resort', 'lat': '42.62083', 'lng': '72.87694'}
# on 23 out of, 453
# {'name': 'Blandford Ski Area', 'lat': '42.18885139', 'lng': '72.90', 'vert': '465'}
# on 24 out of, 453
# {'name': 'Blue Hills Ski Area', 'lat': '42.21528', 'lng': '71.11917', 'vert': '309'}
# on 25 out of, 453
# {'name': 'Blue Hills Ski Area', 'lat': '42.21528', 'lng': '71.11917', 'vert': '309'}
# on 26 out of, 453
# {'name': 'Ski Butternut', 'lat': '42.17806', 'lng': '73.31694', 'vert': '1000'}
# on 27 out of, 453
# {'name': 'Easton Ski Area', 'lat': '42.5387', 'lng': '72.5938\\x'}
# on 28 out of, 453
# {'name': 'Jiminy Peak (ski area)', 'lat': '42.55083', 'lng': '73.29083', 'vert': '1150'}
# on 29 out of, 453
# {'name': 'Jiminy Peak (ski area)', 'lat': '42.55083', 'lng': '73.29083', 'vert': '1150'}
# on 30 out of, 453
# {'name': 'Nashoba Valley Ski Area', 'lat': '42.5419750', 'lng': '71.444', 'vert': '240'}
# on 31 out of, 453
# {'name': 'Otis Ridge', 'lat': '42.1964', 'lng': '73.0988\\x', 'vert': '400'}
# on 32 out of, 453
# {'name': 'Ski Bradford', 'lat': '42.74361', 'lng': '71.05889'}
# on 33 out of, 453
# {'name': 'Ski Ward', 'lat': '42.30556', 'lng': '71.67500', 'vert': '220'}
# on 34 out of, 453
# {'name': 'Wachusett Mountain (ski area)', 'lat': '42.49944', 'lng': '71.88639', 'vert': '1006'}
# on 35 out of, 453
# {'name': 'Arrowhead Recreation Area', 'lat': '43.36278', 'lng': '72.33333'}
# on 36 out of, 453
# {'name': 'Attitash Mountain Resort', 'lat': '44.08222', 'lng': '71.22972', 'vert': '1750'}
# on 37 out of, 453
# {'name': 'Black Mountain Ski Area (New Hampshire)', 'lat': '44.16833', 'lng': '71.16444', 'vert': '1100'}
# on 38 out of, 453
# {'name': 'Bretton Woods Mountain Resort', 'lat': '44.25972', 'lng': '71.46222', 'vert': '1500'}
# on 39 out of, 453
# {'name': 'Cannon Mountain Ski Area', 'lat': '44.15778', 'lng': '71.69889', 'vert': '2330'}
# on 40 out of, 453
# {'name': 'Cranmore Mountain Resort', 'lat': '44.05639', 'lng': '71.11000', 'vert': '1200'}
# on 41 out of, 453
# {'name': 'Crotched Mountain', 'lat': '42.998294108', 'lng': '71.8'}
# on 42 out of, 453
# {'name': 'Dartmouth Skiway', 'lat': '43.78667', 'lng': '72.43389'}
# on 43 out of, 453
# {'name': 'Granite Gorge Ski Area', 'lat': '42.97083', 'lng': '72.21222', 'vert': '390'}
# on 44 out of, 453
# {'name': 'Gunstock Mountain Resort', 'lat': '43.54139', 'lng': '71.36750', 'vert': '1400'}
# on 45 out of, 453
# {'name': 'King Pine', 'lat': '43.87139', 'lng': '71.08944', 'vert': '350'}
# on 46 out of, 453
# {'name': 'Loon Mountain', 'lat': '44.03597', 'lng': '71.62144'}
# on 47 out of, 453
# {'name': 'McIntyre Ski Area', 'lat': '43.00500', 'lng': '71.44000', 'vert': '180'}
# on 48 out of, 453
# {'name': 'McIntyre Ski Area', 'lat': '43.00500', 'lng': '71.44000', 'vert': '180'}
# on 49 out of, 453
# {'name': 'Mount Sunapee Resort', 'lat': '43.33056', 'lng': '72.08000', 'vert': '1513'}
# on 50 out of, 453
# {'name': 'Pats Peak', 'lat': '43.16333', 'lng': '71.79583', 'vert': '770'}
# on 51 out of, 453
# {'name': 'Ragged Mountain Resort', 'lat': '43.48444', 'lng': '71.84222', 'vert': '1250'}
# on 52 out of, 453
# {'name': 'Tenney Mountain Ski Resort', 'lat': '43.73778', 'lng': '71.78361', 'vert': '1400'}
# on 53 out of, 453
# {'name': 'The Balsams Grand Resort Hotel', 'lat': '44.87056', 'lng': '71.30778'}
# on 54 out of, 453
# {'name': 'Waterville Valley Resort', 'lat': '43.96528', 'lng': '71.52778', 'vert': '2020'}
# on 55 out of, 453
# {'name': 'Whaleback (ski area)', 'lat': '43.60139', 'lng': '72.18139', 'vert': '700'}
# on 56 out of, 453
# {'name': 'Wildcat Mountain Ski Area', 'lat': '44.26306', 'lng': '71.23833', 'vert': '2112'}
# on 57 out of, 453
# {'name': 'Yawgoo Valley', 'lat': '41.51694', 'lng': '71.52944'}
# on 58 out of, 453
# {'name': 'Brownsville, Vermont', 'lat': '43.46861', 'lng': '72.47083'}
# on 59 out of, 453
# {'name': 'Bolton Valley', 'lat': '44.419621', 'lng': '72.8499', 'vert': '1625'}
# on 60 out of, 453
# {'name': 'Bromley Mountain', 'lat': '43.22778', 'lng': '72.93861', 'vert': '1334'}
# on 61 out of, 453
# {'name': 'Burke Mountain (Vermont)', 'lat': '44.57083', 'lng': '71.89317'}
# on 62 out of, 453
# {'name': 'Skiing Cochrans', 'lat': '44.396', 'lng': '72.982\\xc2'}
# on 63 out of, 453
# {'name': 'Jay Peak Resort', 'lat': '44.92944', 'lng': '72.53222', 'vert': '2153'}
# on 64 out of, 453
# {'name': 'Killington Ski Resort', 'lat': '43.626', 'lng': '72.798\\xc2', 'vert': '3050'}
# on 65 out of, 453
# {'name': 'Mad River Glen', 'lat': '44.20083', 'lng': '72.92444', 'vert': '2000'}
# on 66 out of, 453
# {'name': 'Magic Mountain Ski Area', 'lat': '43.19278', 'lng': '72.76000', 'vert': '1500'}
# on 67 out of, 453
# {'name': 'Middlebury College Snow Bowl', 'lat': '43.94', 'lng': '72.96\\xc2\\x'}
# on 68 out of, 453
# {'name': 'Mount Snow', 'lat': '42.959835', 'lng': '72.9221'}
# on 69 out of, 453
# {'name': 'Northeast Slopes', 'lat': '44.07250', 'lng': '72.25028', 'vert': '340'}
# on 70 out of, 453
# {'name': 'Okemo Mountain', 'lat': '43.40139', 'lng': '72.71667', 'vert': '2200'}
# on 71 out of, 453
# {'name': 'Pico Mountain', 'lat': '43.66167', 'lng': '72.84250', 'vert': '1967'}
# on 72 out of, 453
# {'name': 'Plymouth Notch, Vermont', 'lat': '43.5299', 'lng': '72.7388\\x'}
# on 73 out of, 453
# {'name': 'Quechee Ski Area', 'lat': '43.6572', 'lng': '72.4431\\x'}
# on 74 out of, 453
# {'name': "Smugglers' Notch Resort", 'lat': '44.57278', 'lng': '72.77611', 'vert': '2610'}
# on 75 out of, 453
# {'name': 'Stowe Mountain Resort', 'lat': '44.53194', 'lng': '72.78750', 'vert': '2360'}
# on 76 out of, 453
# {'name': 'Stratton Mountain Resort', 'lat': '43.11417', 'lng': '72.90667', 'vert': '2003'}
# on 77 out of, 453
# {'name': 'Sugarbush Resort', 'lat': '44.135098', 'lng': '72.8859', 'vert': '2600'}
# on 78 out of, 453
# {'name': 'Suicide Six', 'lat': '43.66389', 'lng': '72.54444', 'vert': '650'}
# on 79 out of, 453
# {'name': 'Wisp Ski Resort', 'lat': '39.55806', 'lng': '79.36306', 'vert': '700'}
# on 80 out of, 453
# {'name': 'Big Snow American Dream', 'lat': '40.81111', 'lng': '74.07000'}
# on 81 out of, 453
# {'name': 'Campgaw Mountain', 'lat': '41.0542633', 'lng': '74.199'}
# on 82 out of, 453
# {'name': 'Hidden Valley (New Jersey)', 'lat': '41.1856000', 'lng': '74.480', 'vert': '620'}
# on 83 out of, 453
# {'name': 'Mountain Creek', 'lat': '41.181', 'lng': '74.513\\xc2'}
# on 84 out of, 453
# {'name': 'Mountain Creek', 'lat': '41.181', 'lng': '74.513\\xc2'}
# on 85 out of, 453
# {'name': 'Belleayre Mountain', 'lat': '42.1422139', 'lng': '74.510'}
# on 86 out of, 453
# {'name': 'Belleayre Mountain', 'lat': '42.1422139', 'lng': '74.510'}
# on 87 out of, 453
# {'name': 'Belleayre Mountain', 'lat': '42.1422139', 'lng': '74.510'}
# on 88 out of, 453
# {'name': 'Bristol Mountain Ski Resort', 'lat': '42.745', 'lng': '77.404444\\', 'vert': '1150'}
# on 89 out of, 453
# {'name': 'Bristol Mountain Ski Resort', 'lat': '42.745', 'lng': '77.404444\\', 'vert': '1150'}
# on 90 out of, 453
# {'name': 'Catamount Ski Area', 'lat': '42.171457', 'lng': '73.4777', 'vert': '1000'}
# on 91 out of, 453
# {'name': 'Catamount Ski Area', 'lat': '42.171457', 'lng': '73.4777', 'vert': '1000'}
# on 92 out of, 453
# {'name': 'Gore Mountain (ski resort)', 'lat': '43.67222', 'lng': '74.00694', 'vert': '2537'}
# on 93 out of, 453
# {'name': 'Greek Peak Mountain Resort', 'lat': '42.5085996', 'lng': '76.146'}
# on 94 out of, 453
# {'name': 'Greek Peak Mountain Resort', 'lat': '42.5085996', 'lng': '76.146'}
# on 95 out of, 453
# {'name': 'Holiday Valley (ski resort)', 'lat': '42.26250', 'lng': '78.66806', 'vert': '750'}
# on 96 out of, 453
# {'name': 'Holiday Valley (ski resort)', 'lat': '42.26250', 'lng': '78.66806', 'vert': '750'}
# on 97 out of, 453
# {'name': 'Holiday Valley (ski resort)', 'lat': '42.26250', 'lng': '78.66806', 'vert': '750'}
# on 98 out of, 453
# {'name': 'Hunter Mountain (ski area)', 'lat': '42.200278', 'lng': '74.2302', 'vert': '1600'}
# on 99 out of, 453
# {'name': 'Hunter Mountain (ski area)', 'lat': '42.200278', 'lng': '74.2302', 'vert': '1600'}
# on 100 out of, 453
# {'name': 'Hunter Mountain (ski area)', 'lat': '42.200278', 'lng': '74.2302', 'vert': '1600'}
# on 101 out of, 453
# {'name': 'Hunter Mountain (ski area)', 'lat': '42.200278', 'lng': '74.2302', 'vert': '1600'}
# on 102 out of, 453
# {'name': 'McCauley Mountain (New York)', 'lat': '43.6925676', 'lng': '74.961'}
# on 103 out of, 453
# {'name': 'McCauley Mountain (New York)', 'lat': '43.6925676', 'lng': '74.961'}
# on 104 out of, 453
# {'name': "Peek'n Peak", 'lat': '42.06250', 'lng': '79.73667', 'vert': '400'}
# on 105 out of, 453
# {'name': 'Plattekill Mountain', 'lat': '42.290251', 'lng': '74.6536', 'vert': '1100'}
# on 106 out of, 453
# {'name': 'Plattekill Mountain', 'lat': '42.290251', 'lng': '74.6536', 'vert': '1100'}
# on 107 out of, 453
# {'name': 'Plattekill Mountain', 'lat': '42.290251', 'lng': '74.6536', 'vert': '1100'}
# on 108 out of, 453
# {'name': 'Plattekill Mountain', 'lat': '42.290251', 'lng': '74.6536', 'vert': '1100'}
# on 109 out of, 453
# {'name': 'Plattekill Mountain', 'lat': '42.290251', 'lng': '74.6536', 'vert': '1100'}
# on 110 out of, 453
# {'name': 'Plattekill Mountain', 'lat': '42.290251', 'lng': '74.6536', 'vert': '1100'}
# on 111 out of, 453
# {'name': 'Thunder Ridge Ski Area', 'lat': '41.50722', 'lng': '73.58111', 'vert': '403'}
# on 112 out of, 453
# {'name': 'Titus Mountain', 'lat': '44.76333', 'lng': '74.23528'}
# on 113 out of, 453
# {'name': 'Titus Mountain', 'lat': '44.76333', 'lng': '74.23528'}
# on 114 out of, 453
# {'name': 'West Mountain (ski area)', 'lat': '43.28556', 'lng': '73.72833', 'vert': '1010'}
# on 115 out of, 453
# {'name': 'West Mountain (ski area)', 'lat': '43.28556', 'lng': '73.72833', 'vert': '1010'}
# on 116 out of, 453
# {'name': 'Whiteface Mountain', 'lat': '44.36583', 'lng': '73.90278'}
# on 117 out of, 453
# {'name': 'Windham Mountain', 'lat': '42.29167', 'lng': '74.25944', 'vert': '1600'}
# on 118 out of, 453
# {'name': 'Windham Mountain', 'lat': '42.29167', 'lng': '74.25944', 'vert': '1600'}
# on 119 out of, 453
# {'name': 'Bear Creek Ski and Recreation Area', 'lat': '40.47611', 'lng': '75.62583'}
# on 120 out of, 453
# {'name': 'Bear Creek Ski and Recreation Area', 'lat': '40.47611', 'lng': '75.62583'}
# on 121 out of, 453
# {'name': 'Blue Mountain Resort', 'lat': '40.82222', 'lng': '75.51333', 'vert': '1082'}
# on 122 out of, 453
# {'name': 'Boyce Park', 'lat': '40.46556', 'lng': '79.74528'}
# on 123 out of, 453
# {'name': 'Camelback Mountain Resort', 'lat': '41.05139', 'lng': '75.35528', 'vert': '800'}
# on 124 out of, 453
# {'name': 'Camelback Mountain Resort', 'lat': '41.05139', 'lng': '75.35528', 'vert': '800'}
# on 125 out of, 453
# {'name': 'Elk Mountain Ski Area', 'lat': '41.721', 'lng': '75.559\\xc2', 'vert': '925'}
# on 126 out of, 453
# {'name': 'Hidden Valley Resort (Pennsylvania)', 'lat': '40.058042', 'lng': '79.2582', 'vert': '470'}
# on 127 out of, 453
# {'name': 'Jack Frost Ski Resort', 'lat': '41.111', 'lng': '75.652\\xc2'}
# on 128 out of, 453
# {'name': 'Jack Frost Ski Resort', 'lat': '41.111', 'lng': '75.652\\xc2'}
# on 129 out of, 453
# {'name': 'Liberty Mountain Resort', 'lat': '39.763500', 'lng': '77.3750', 'vert': '620'}
# on 130 out of, 453
# {'name': 'Mount Pleasant of Edinboro', 'lat': '41.85111', 'lng': '80.07028', 'vert': '350'}
# on 131 out of, 453
# {'name': 'Seven Springs Mountain Resort', 'lat': '40.02306', 'lng': '79.29278', 'vert': '750'}
# on 132 out of, 453
# {'name': 'Shawnee Mountain Ski Area', 'lat': '41.04083', 'lng': '75.08333', 'vert': '700'}
# on 133 out of, 453
# {'name': 'Ski Big Bear', 'lat': '41.52333', 'lng': '75.02500'}
# on 134 out of, 453
# {'name': 'Ski Big Bear', 'lat': '41.52333', 'lng': '75.02500'}
# on 135 out of, 453
# {'name': 'Roundtop Mountain Resort', 'lat': '40.108', 'lng': '76.926\\xc2', 'vert': '600'}
# on 136 out of, 453
# {'name': 'Roundtop Mountain Resort', 'lat': '40.108', 'lng': '76.926\\xc2', 'vert': '600'}
# on 137 out of, 453
# {'name': 'Roundtop Mountain Resort', 'lat': '40.108', 'lng': '76.926\\xc2', 'vert': '600'}
# on 138 out of, 453
# {'name': 'Montage Mountain Ski Resort', 'lat': '41.3533', 'lng': '75.6592\\x', 'vert': '1000'}
# on 139 out of, 453
# {'name': 'Tussey Mountain Ski Area', 'lat': '40.7682', 'lng': '77.7520\\x', 'vert': '500'}
# on 140 out of, 453
# {'name': 'Whitetail Ski Resort', 'lat': '39.74167', 'lng': '77.93278', 'vert': '935'}
# on 141 out of, 453
# {'name': 'Whitetail Ski Resort', 'lat': '39.74167', 'lng': '77.93278', 'vert': '935'}
# on 142 out of, 453
# {'name': 'Appalachian Ski Mountain', 'lat': '36.174', 'lng': '81.662\\xc2'}
# on 143 out of, 453
# {'name': 'Cataloochee Ski Area', 'lat': '35.563', 'lng': '83.090\\xc2'}
# on 144 out of, 453
# {'name': 'Cataloochee Ski Area', 'lat': '35.563', 'lng': '83.090\\xc2'}
# on 145 out of, 453
# {'name': 'Cataloochee Ski Area', 'lat': '35.563', 'lng': '83.090\\xc2'}
# on 146 out of, 453
# {'name': 'Cataloochee Ski Area', 'lat': '35.563', 'lng': '83.090\\xc2'}
# on 147 out of, 453
# {'name': 'Wolf Ridge Ski Resort', 'lat': '35.955', 'lng': '82.509\\xc2'}
# on 148 out of, 453
# {'name': 'Ober Gatlinburg', 'lat': '35.708969', 'lng': '83.5215'}
# on 149 out of, 453
# {'name': 'Ober Gatlinburg', 'lat': '35.708969', 'lng': '83.5215'}
# on 150 out of, 453
# {'name': 'Bryce Resort', 'lat': '38.81750', 'lng': '78.76583', 'vert': '500'}
# on 151 out of, 453
# {'name': 'Massanutten Mountain', 'lat': '38.643028', 'lng': '78.6120'}
# on 152 out of, 453
# {'name': 'The Omni Homestead Resort', 'lat': '37.9954722', 'lng': '79.829'}
# on 153 out of, 453
# {'name': 'Wintergreen Resort', 'lat': '37.93000', 'lng': '78.94167', 'vert': '1003'}
# on 154 out of, 453
# {'name': 'Canaan Valley Resort State Park', 'lat': '39.02361', 'lng': '79.46583'}
# on 155 out of, 453
# {'name': 'Canaan Valley Resort State Park', 'lat': '39.02361', 'lng': '79.46583'}
# on 156 out of, 453
# {'name': 'Snowshoe Mountain', 'lat': '38.40889', 'lng': '79.99472', 'vert': '1500'}
# on 157 out of, 453
# {'name': 'Snowshoe Mountain', 'lat': '38.40889', 'lng': '79.99472', 'vert': '1500'}
# on 158 out of, 453
# {'name': 'Winterplace Ski Resort', 'lat': '37.59000', 'lng': '81.11500', 'vert': '603'}
# on 159 out of, 453
# {'name': 'Winterplace Ski Resort', 'lat': '37.59000', 'lng': '81.11500', 'vert': '603'}
# on 160 out of, 453
# {'name': 'Winterplace Ski Resort', 'lat': '37.59000', 'lng': '81.11500', 'vert': '603'}
# on 161 out of, 453
# {'name': 'Winterplace Ski Resort', 'lat': '37.59000', 'lng': '81.11500', 'vert': '603'}
# on 162 out of, 453
# {'name': 'Ski Snowstar', 'lat': '41.4250', 'lng': '90.7438\\x'}
# on 163 out of, 453
# {'name': 'Ski Snowstar', 'lat': '41.4250', 'lng': '90.7438\\x'}
# on 164 out of, 453
# {'name': 'Paoli Peaks', 'lat': '38.55778', 'lng': '86.51028', 'vert': '300'}
# on 165 out of, 453
# {'name': 'Perfect North Slopes', 'lat': '39.149208', 'lng': '84.8865', 'vert': '400'}
# on 166 out of, 453
# {'name': 'Perfect North Slopes', 'lat': '39.149208', 'lng': '84.8865', 'vert': '400'}
# on 167 out of, 453
# {'name': 'Perfect North Slopes', 'lat': '39.149208', 'lng': '84.8865', 'vert': '400'}
# on 168 out of, 453
# {'name': 'Perfect North Slopes', 'lat': '39.149208', 'lng': '84.8865', 'vert': '400'}
# on 169 out of, 453
# {'name': 'Perfect North Slopes', 'lat': '39.149208', 'lng': '84.8865', 'vert': '400'}
# on 170 out of, 453
# {'name': 'Perfect North Slopes', 'lat': '39.149208', 'lng': '84.8865', 'vert': '400'}
# on 171 out of, 453
# {'name': 'Perfect North Slopes', 'lat': '39.149208', 'lng': '84.8865', 'vert': '400'}
# on 172 out of, 453
# {'name': 'Perfect North Slopes', 'lat': '39.149208', 'lng': '84.8865', 'vert': '400'}
# on 173 out of, 453
# {'name': 'Big Powderhorn Mountain', 'lat': '46.50417', 'lng': '90.09611'}
# on 174 out of, 453
# {'name': 'Big Powderhorn Mountain', 'lat': '46.50417', 'lng': '90.09611'}
# on 175 out of, 453
# {'name': 'Blackjack Ski Resort (Bessemer, Michigan)', 'lat': '46.5021', 'lng': '90.0046\\x', 'vert': '490'}
# on 176 out of, 453
# {'name': 'Boyne Highlands', 'lat': '45.47083', 'lng': '84.93472', 'vert': '552'}
# on 177 out of, 453
# {'name': 'Boyne Mountain Resort', 'lat': '45.16389', 'lng': '84.93278'}
# on 178 out of, 453
# {'name': 'Caberfae Peaks Ski &amp; Golf Resort', 'lat': '44.24972', 'lng': '85.72500', 'vert': '485'}
# on 179 out of, 453
# {'name': 'Caberfae Peaks Ski &amp; Golf Resort', 'lat': '44.24972', 'lng': '85.72500', 'vert': '485'}
# on 180 out of, 453
# {'name': 'Caberfae Peaks Ski &amp; Golf Resort', 'lat': '44.24972', 'lng': '85.72500', 'vert': '485'}
# on 181 out of, 453
# {'name': 'Crystal Mountain (Michigan)', 'lat': '44.52000', 'lng': '85.99222', 'vert': '375'}
# on 182 out of, 453
# {'name': 'Crystal Mountain (Michigan)', 'lat': '44.52000', 'lng': '85.99222', 'vert': '375'}
# on 183 out of, 453
# {'name': 'Crystal Mountain (Michigan)', 'lat': '44.52000', 'lng': '85.99222', 'vert': '375'}
# on 184 out of, 453
# {'name': 'Crystal Mountain (Michigan)', 'lat': '44.52000', 'lng': '85.99222', 'vert': '375'}
# on 185 out of, 453
# {'name': 'Indianhead Mountain', 'lat': '46.50000', 'lng': '89.97083', 'vert': '520'}
# on 186 out of, 453
# {'name': 'Marquette Mountain', 'lat': '46.508', 'lng': '87.42\\xc2\\'}
# on 187 out of, 453
# {'name': 'Mont Ripley', 'lat': '47.12917', 'lng': '88.55944'}
# on 188 out of, 453
# {'name': 'Mount Bohemia', 'lat': '47.39167', 'lng': '88.01361', 'vert': '900'}
# on 189 out of, 453
# {'name': 'Mount Brighton', 'lat': '42.53806', 'lng': '83.80694'}
# on 190 out of, 453
# {'name': 'Mount Brighton', 'lat': '42.53806', 'lng': '83.80694'}
# on 191 out of, 453
# {'name': 'Mount Brighton', 'lat': '42.53806', 'lng': '83.80694'}
# on 192 out of, 453
# {'name': 'Mount Brighton', 'lat': '42.53806', 'lng': '83.80694'}
# on 193 out of, 453
# {'name': 'Mount Brighton', 'lat': '42.53806', 'lng': '83.80694'}
# on 194 out of, 453
# {'name': "Mulligan's Hollow Ski Bowl", 'lat': '43.0564', 'lng': '86.2393\\x'}
# on 195 out of, 453
# {'name': "Mulligan's Hollow Ski Bowl", 'lat': '43.0564', 'lng': '86.2393\\x'}
# on 196 out of, 453
# {'name': "Nub's Nob", 'lat': '45.47', 'lng': '84.903\\xc2\\'}
# on 197 out of, 453
# {'name': "Nub's Nob", 'lat': '45.47', 'lng': '84.903\\xc2\\'}
# on 198 out of, 453
# {'name': "Nub's Nob", 'lat': '45.47', 'lng': '84.903\\xc2\\'}
# on 199 out of, 453
# {'name': 'Pine Knob', 'lat': '42.7422524', 'lng': '83.367'}
# on 200 out of, 453
# {'name': 'Pine Knob', 'lat': '42.7422524', 'lng': '83.367'}
# on 201 out of, 453
# {'name': 'Porcupine Mountains', 'lat': '46.78111', 'lng': '89.68083'}
# on 202 out of, 453
# {'name': 'Porcupine Mountains', 'lat': '46.78111', 'lng': '89.68083'}
# on 203 out of, 453
# {'name': 'Ski Brule', 'lat': '46.028', 'lng': '88.701\\xc2'}
# on 204 out of, 453
# {'name': 'Ski Brule', 'lat': '46.028', 'lng': '88.701\\xc2'}
# on 205 out of, 453
# {'name': 'Ski Brule', 'lat': '46.028', 'lng': '88.701\\xc2'}
# on 206 out of, 453
# {'name': 'Timber Ridge Ski Area', 'lat': '42.391711', 'lng': '85.7790'}
# on 207 out of, 453
# {'name': 'Timber Ridge Ski Area', 'lat': '42.391711', 'lng': '85.7790'}
# on 208 out of, 453
# {'name': 'Afton Alps', 'lat': '44.85556', 'lng': '92.78917', 'vert': '350'}
# on 209 out of, 453
# {'name': 'Afton Alps', 'lat': '44.85556', 'lng': '92.78917', 'vert': '350'}
# on 210 out of, 453
# {'name': 'Buck Hill', 'lat': '44.724', 'lng': '93.283\\xc2'}
# on 211 out of, 453
# {'name': 'Buena Vista Ski Area', 'lat': '47.65806', 'lng': '94.87917'}
# on 212 out of, 453
# {'name': 'Buena Vista Ski Area', 'lat': '47.65806', 'lng': '94.87917'}
# on 213 out of, 453
# {'name': 'Buena Vista Ski Area', 'lat': '47.65806', 'lng': '94.87917'}
# on 214 out of, 453
# {'name': 'Buena Vista Ski Area', 'lat': '47.65806', 'lng': '94.87917'}
# on 215 out of, 453
# {'name': 'Buena Vista Ski Area', 'lat': '47.65806', 'lng': '94.87917'}
# on 216 out of, 453
# {'name': 'Hyland Hills Ski Area', 'lat': '44.844', 'lng': '93.364\\xc2'}
# on 217 out of, 453
# {'name': 'Lutsen Mountains', 'lat': '47.664', 'lng': '90.714\\xc2', 'vert': '825'}
# on 218 out of, 453
# {'name': 'Lutsen Mountains', 'lat': '47.664', 'lng': '90.714\\xc2', 'vert': '825'}
# on 219 out of, 453
# {'name': 'Mount Kato', 'lat': '44.13139', 'lng': '94.03639', 'vert': '240'}
# on 220 out of, 453
# {'name': 'Mount Kato', 'lat': '44.13139', 'lng': '94.03639', 'vert': '240'}
# on 221 out of, 453
# {'name': 'Mount Kato', 'lat': '44.13139', 'lng': '94.03639', 'vert': '240'}
# on 222 out of, 453
# {'name': 'Spirit Mountain (ski area)', 'lat': '46.71944', 'lng': '92.21806', 'vert': '678'}
# on 223 out of, 453
# {'name': 'Welch Village', 'lat': '44.56056', 'lng': '92.72722'}
# on 224 out of, 453
# {'name': 'Wild Mountain', 'lat': '45.48889', 'lng': '92.70556'}
# on 225 out of, 453
# {'name': 'Hidden Valley Ski Area', 'lat': '38.535578', 'lng': '90.6528', 'vert': '320'}
# on 226 out of, 453
# {'name': 'Snow Creek (ski resort)', 'lat': '39.468651', 'lng': '94.9719', 'vert': '300'}
# on 227 out of, 453
# {'name': 'Bottineau Winter Park', 'lat': '48.951', 'lng': '100.473\\xc'}
# on 228 out of, 453
# {'name': 'Frost Fire Park', 'lat': '48.912', 'lng': '98.068\\xc2'}
# on 229 out of, 453
# {'name': 'Huff Hills', 'lat': '46.62694', 'lng': '100.7233'}
# on 230 out of, 453
# {'name': 'Alpine Valley Ski Area', 'lat': '41.5303', 'lng': '81.2662\\x', 'vert': '230'}
# on 231 out of, 453
# {'name': 'Boston Mills/Brandywine Ski Resort', 'lat': '41.26417', 'lng': '81.56500', 'vert': '240'}
# on 232 out of, 453
# {'name': 'Mad River Mountain', 'lat': '40.3163167', 'lng': '83.680'}
# on 233 out of, 453
# {'name': 'Mad River Mountain', 'lat': '40.3163167', 'lng': '83.680'}
# on 234 out of, 453
# {'name': 'Mad River Mountain', 'lat': '40.3163167', 'lng': '83.680'}
# on 235 out of, 453
# {'name': 'Mystic Miner Ski Resort', 'lat': '44.3084333', 'lng': '103.81', 'vert': '699'}
# on 236 out of, 453
# {'name': 'Great Bear Recreation Park', 'lat': '43.5821000', 'lng': '96.664', 'vert': '178'}
# on 237 out of, 453
# {'name': 'Terry Peak', 'lat': '44.329', 'lng': '103.835\\xc', 'vert': '1164'}
# on 238 out of, 453
# {'name': 'Alpine Valley Resort (Wisconsin)', 'lat': '42.736', 'lng': '88.428\\xc2'}
# on 239 out of, 453
# {'name': 'Alpine Valley Resort (Wisconsin)', 'lat': '42.736', 'lng': '88.428\\xc2'}
# on 240 out of, 453
# {'name': 'Alpine Valley Resort (Wisconsin)', 'lat': '42.736', 'lng': '88.428\\xc2'}
# on 241 out of, 453
# {'name': 'Alpine Valley Resort (Wisconsin)', 'lat': '42.736', 'lng': '88.428\\xc2'}
# on 242 out of, 453
# {'name': 'Alpine Valley Resort (Wisconsin)', 'lat': '42.736', 'lng': '88.428\\xc2'}
# on 243 out of, 453
# {'name': 'Alpine Valley Resort (Wisconsin)', 'lat': '42.736', 'lng': '88.428\\xc2'}
# on 244 out of, 453
# {'name': 'Alpine Valley Resort (Wisconsin)', 'lat': '42.736', 'lng': '88.428\\xc2'}
# on 245 out of, 453
# {'name': 'Cascade Mountain (ski area)', 'lat': '43.5039278', 'lng': '89.518', 'vert': '450'}
# on 246 out of, 453
# {'name': 'Cascade Mountain (ski area)', 'lat': '43.5039278', 'lng': '89.518', 'vert': '450'}
# on 247 out of, 453
# {'name': 'Cascade Mountain (ski area)', 'lat': '43.5039278', 'lng': '89.518', 'vert': '450'}
# on 248 out of, 453
# {'name': 'Cascade Mountain (ski area)', 'lat': '43.5039278', 'lng': '89.518', 'vert': '450'}
# on 249 out of, 453
# {'name': "Devil's Head Resort", 'lat': '43.42306', 'lng': '89.62694', 'vert': '500'}
# on 250 out of, 453
# {'name': "Devil's Head Resort", 'lat': '43.42306', 'lng': '89.62694', 'vert': '500'}
# on 251 out of, 453
# {'name': 'Granite Peak Ski Area', 'lat': '44.92861', 'lng': '89.68250', 'vert': '700'}
# on 252 out of, 453
# {'name': 'Granite Peak Ski Area', 'lat': '44.92861', 'lng': '89.68250', 'vert': '700'}
# on 253 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 254 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 255 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 256 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 257 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 258 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 259 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 260 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 261 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 262 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 263 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 264 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 265 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 266 out of, 453
# {'name': 'Kettlebowl', 'lat': '45.271323000', 'lng': '88.9'}
# on 267 out of, 453
# {'name': 'Telemark Lodge', 'lat': '46.190056', 'lng': '91.2476'}
# on 268 out of, 453
# {'name': 'Telemark Lodge', 'lat': '46.190056', 'lng': '91.2476'}
# on 269 out of, 453
# {'name': 'Trollhaugen', 'lat': '45.35125', 'lng': '92.61801'}
# on 270 out of, 453
# {'name': 'Tyrol Basin', 'lat': '43.042647', 'lng': '89.7777', 'vert': '260'}
# on 271 out of, 453
# {'name': 'Tyrol Basin', 'lat': '43.042647', 'lng': '89.7777', 'vert': '260'}
# on 272 out of, 453
# {'name': 'Tyrol Basin', 'lat': '43.042647', 'lng': '89.7777', 'vert': '260'}
# on 273 out of, 453
# {'name': 'Wilmot Mountain', 'lat': '42.50000', 'lng': '88.18889', 'vert': '190'}
# on 274 out of, 453
# {'name': 'Arizona Snowbowl', 'lat': '35.330', 'lng': '111.705\\xc'}
# on 275 out of, 453
# {'name': 'Elk Ridge Ski Area', 'lat': '35.21056', 'lng': '112.1925'}
# on 276 out of, 453
# {'name': 'Mount Lemmon Ski Valley', 'lat': '32.45222', 'lng': '110.7838'}
# on 277 out of, 453
# {'name': 'Sunrise Park Resort', 'lat': '33.97333', 'lng': '109.5647', 'vert': '1900'}
# on 278 out of, 453
# {'name': 'Arapahoe Basin', 'lat': '39.64167', 'lng': '105.8716'}
# on 279 out of, 453
# {'name': 'Arapahoe Basin', 'lat': '39.64167', 'lng': '105.8716'}
# on 280 out of, 453
# {'name': 'Aspen Highlands', 'lat': '39.18111', 'lng': '106.8563', 'vert': '3638'}
# on 281 out of, 453
# {'name': 'Aspen Mountain (ski area)', 'lat': '39.18639', 'lng': '106.8186'}
# on 282 out of, 453
# {'name': 'Buttermilk (ski area)', 'lat': '39.20500', 'lng': '106.8605', 'vert': '2030'}
# on 283 out of, 453
# {'name': 'Snowmass (ski area)', 'lat': '39.1956', 'lng': '106.9513\\', 'vert': '4406'}
# on 284 out of, 453
# {'name': 'Beaver Creek Resort', 'lat': '39.63139', 'lng': '106.5216', 'vert': '3340'}
# on 285 out of, 453
# {'name': 'Breckenridge Ski Resort', 'lat': '39.480', 'lng': '106.067\\xc'}
# on 286 out of, 453
# {'name': 'Breckenridge Ski Resort', 'lat': '39.480', 'lng': '106.067\\xc'}
# on 287 out of, 453
# {'name': 'Copper Mountain (Colorado)', 'lat': '39.50167', 'lng': '106.1563'}
# on 288 out of, 453
# {'name': 'Copper Mountain (Colorado)', 'lat': '39.50167', 'lng': '106.1563'}
# on 289 out of, 453
# {'name': 'Crested Butte Mountain Resort', 'lat': '38.89972', 'lng': '106.9650'}
# on 290 out of, 453
# {'name': 'Echo Mountain Resort', 'lat': '39.68500', 'lng': '105.5194', 'vert': '600'}
# on 291 out of, 453
# {'name': 'Eldora Mountain Resort', 'lat': '39.93750', 'lng': '105.5836', 'vert': '1240'}
# on 292 out of, 453
# {'name': 'Hesperus Ski Area', 'lat': '37.29778', 'lng': '108.0550'}
# on 293 out of, 453
# {'name': 'Howelsen Hill Ski Area', 'lat': '40.483', 'lng': '106.839\\xc'}
# on 294 out of, 453
# {'name': 'Kendall Mountain Ski Area', 'lat': '37.81135', 'lng': '107.6565'}
# on 295 out of, 453
# {'name': 'Keystone Resort', 'lat': '39.60500', 'lng': '105.9541'}
# on 296 out of, 453
# {'name': 'Keystone Resort', 'lat': '39.60500', 'lng': '105.9541'}
# on 297 out of, 453
# {'name': 'Loveland Ski Area', 'lat': '39.680', 'lng': '105.897\\xc'}
# on 298 out of, 453
# {'name': 'Loveland Ski Area', 'lat': '39.680', 'lng': '105.897\\xc'}
# on 299 out of, 453
# {'name': 'Monarch Ski Area', 'lat': '38.51250', 'lng': '106.3325'}
# on 300 out of, 453
# {'name': 'Monarch Ski Area', 'lat': '38.51250', 'lng': '106.3325'}
# on 301 out of, 453
# {'name': 'Powderhorn Resort', 'lat': '39.06306', 'lng': '108.1555', 'vert': '1650'}
# on 302 out of, 453
# {'name': 'Purgatory Resort', 'lat': '37.62972', 'lng': '107.8144', 'vert': '2029'}
# on 303 out of, 453
# {'name': 'Silverton Mountain', 'lat': '37.88470', 'lng': '107.6652'}
# on 304 out of, 453
# {'name': 'Ski Cooper', 'lat': '39.360', 'lng': '106.302\\xc', 'vert': '1200'}
# on 305 out of, 453
# {'name': 'Ski Cooper', 'lat': '39.360', 'lng': '106.302\\xc', 'vert': '1200'}
# on 306 out of, 453
# {'name': 'Steamboat Ski Resort', 'lat': '40.459', 'lng': '106.803\\xc'}
# on 307 out of, 453
# {'name': 'Sunlight Ski Area', 'lat': '39.399806', 'lng': '107.339', 'vert': '2010'}
# on 308 out of, 453
# {'name': 'Telluride Ski Resort', 'lat': '37.93639', 'lng': '107.8202', 'vert': '4425'}
# on 309 out of, 453
# {'name': 'Vail Ski Resort', 'lat': '39.639', 'lng': '106.374\\xc'}
# on 310 out of, 453
# {'name': 'Winter Park Resort', 'lat': '39.88694', 'lng': '105.7625'}
# on 311 out of, 453
# {'name': 'Wolf Creek ski area', 'lat': '37.47222', 'lng': '106.7933'}
# on 312 out of, 453
# {'name': 'Bald Mountain Ski Area', 'lat': '46.57', 'lng': '115.87\\xc2\\'}
# on 313 out of, 453
# {'name': 'Bogus Basin', 'lat': '43.764', 'lng': '116.104\\xc', 'vert': '1790'}
# on 314 out of, 453
# {'name': 'Brundage Mountain', 'lat': '45.005', 'lng': '116.155\\xc', 'vert': '1800'}
# on 315 out of, 453
# {'name': 'Cottonwood Butte', 'lat': '46.0755', 'lng': '116.4528\\'}
# on 316 out of, 453
# {'name': 'Kelly Canyon', 'lat': '43.64583', 'lng': '111.6300', 'vert': '1000'}
# on 317 out of, 453
# {'name': 'Little Ski Hill', 'lat': '44.93000', 'lng': '116.1630'}
# on 318 out of, 453
# {'name': 'Lookout Pass Ski and Recreation Area', 'lat': '47.453', 'lng': '115.707\\xc', 'vert': '1150'}
# on 319 out of, 453
# {'name': 'Lost Trail Powder Mountain', 'lat': '45.692', 'lng': '113.952\\xc', 'vert': '1800'}
# on 320 out of, 453
# {'name': 'Magic Mountain Resort', 'lat': '42.188306', 'lng': '114.286'}
# on 321 out of, 453
# {'name': 'Pebble Creek, Idaho', 'lat': '42.778', 'lng': '112.160\\xc', 'vert': '2911'}
# on 322 out of, 453
# {'name': 'Sandpoint, Idaho', 'lat': '48.267', 'lng': '116.567\\xc'}
# on 323 out of, 453
# {'name': 'Pomerelle', 'lat': '42.318', 'lng': '113.608\\xc', 'vert': '1002'}
# on 324 out of, 453
# {'name': 'Rotarun Ski Area', 'lat': '43.497500', 'lng': '114.366', 'vert': '475'}
# on 325 out of, 453
# {'name': 'Schweitzer Mountain', 'lat': '48.367', 'lng': '116.623\\xc', 'vert': '2440'}
# on 326 out of, 453
# {'name': 'Silver Mountain (Idaho)', 'lat': '47.495', 'lng': '116.135\\xc', 'vert': '2197'}
# on 327 out of, 453
# {'name': 'Snowhaven', 'lat': '45.869000', 'lng': '116.090'}
# on 328 out of, 453
# {'name': 'Soldier Mountain', 'lat': '43.485', 'lng': '114.830\\xc', 'vert': '1425'}
# on 329 out of, 453
# {'name': 'Bald Mountain (Idaho)', 'lat': '43.65500', 'lng': '114.4091', 'vert': '3400'}
# on 330 out of, 453
# {'name': 'Tamarack Resort', 'lat': '44.671', 'lng': '116.123\\xc', 'vert': '2760'}
# on 331 out of, 453
# {'name': 'Havre, Montana', 'lat': '48.550', 'lng': '109.683\\xc'}
# on 332 out of, 453
# {'name': 'Big Sky Resort', 'lat': '45.25000', 'lng': '111.4166', 'vert': '4350'}
# on 333 out of, 453
# {'name': 'Blacktail Mountain Ski Area', 'lat': '48.01306', 'lng': '114.2469'}
# on 334 out of, 453
# {'name': 'Bridger Bowl Ski Area', 'lat': '45.818', 'lng': '110.897\\xc', 'vert': '2600'}
# on 335 out of, 453
# {'name': 'Discovery Ski Area', 'lat': '46.25639', 'lng': '113.2419'}
# on 336 out of, 453
# {'name': 'Great Divide Montana', 'lat': '46.7497', 'lng': '112.3043\\'}
# on 337 out of, 453
# {'name': 'Lost Trail Powder Mountain', 'lat': '45.692', 'lng': '113.952\\xc', 'vert': '1800'}
# on 338 out of, 453
# {'name': 'Maverick Mountain Ski Area', 'lat': '45.43500', 'lng': '113.1294'}
# on 339 out of, 453
# {'name': 'Montana Snowbowl', 'lat': '47.02', 'lng': '114.0\\xc2\\x', 'vert': '2600'}
# on 340 out of, 453
# {'name': 'Moonlight Basin', 'lat': '45.31417', 'lng': '111.4508'}
# on 341 out of, 453
# {'name': 'Red Lodge Mountain', 'lat': '45.191', 'lng': '109.335\\xc', 'vert': '2400'}
# on 342 out of, 453
# {'name': 'Showdown Ski Area', 'lat': '46.83861', 'lng': '110.7088'}
# on 343 out of, 453
# {'name': 'Teton Pass Ski Area', 'lat': '47.92806', 'lng': '112.8152'}
# on 344 out of, 453
# {'name': 'Turner Mountain Ski Resort', 'lat': '48.605', 'lng': '115.63\\xc2', 'vert': '2110'}
# on 345 out of, 453
# {'name': 'Whitefish Mountain Resort', 'lat': '48.50', 'lng': '114.34\\xc2\\', 'vert': '2353'}
# on 346 out of, 453
# {'name': 'Yellowstone Club', 'lat': '45.2313833', 'lng': '111.45'}
# on 347 out of, 453
# {'name': 'Angel Fire Resort', 'lat': '36.38750', 'lng': '105.2733'}
# on 348 out of, 453
# {'name': 'Pajarito Mountain Ski Area', 'lat': '35.89417', 'lng': '106.3902'}
# on 349 out of, 453
# {'name': 'Pajarito Mountain Ski Area', 'lat': '35.89417', 'lng': '106.3902'}
# on 350 out of, 453
# {'name': 'Sandia Peak Tramway', 'lat': '35.19056', 'lng': '106.4794'}
# on 351 out of, 453
# {'name': 'Sipapu Ski &amp; Summer Resort', 'lat': '36.154211', 'lng': '105.548', 'vert': '1055'}
# on 352 out of, 453
# {'name': 'Ski Apache', 'lat': '33.39722', 'lng': '105.7991', 'vert': '1900'}
# on 353 out of, 453
# {'name': 'Ski Cloudcroft', 'lat': '32.9507083', 'lng': '105.70'}
# on 354 out of, 453
# {'name': 'Ski Santa Fe', 'lat': '35.7963250', 'lng': '105.80'}
# on 355 out of, 453
# {'name': 'Taos Ski Valley, New Mexico', 'lat': '36.59778', 'lng': '105.4450'}
# on 356 out of, 453
# {'name': 'Alta Ski Area', 'lat': '40.58083', 'lng': '111.6372', 'vert': '2538'}
# on 357 out of, 453
# {'name': 'Beaver Mountain', 'lat': '41.968', 'lng': '111.541\\xc', 'vert': '1600'}
# on 358 out of, 453
# {'name': 'Brian Head Ski Resort', 'lat': '37.683', 'lng': '112.833\\xc', 'vert': '1707'}
# on 359 out of, 453
# {'name': 'Brighton Ski Resort', 'lat': '40.60000', 'lng': '111.5833', 'vert': '1750'}
# on 360 out of, 453
# {'name': 'Cherry Peak Resort', 'lat': '41.92639', 'lng': '111.7566', 'vert': '1265'}
# on 361 out of, 453
# {'name': 'Deer Valley', 'lat': '40.62278', 'lng': '111.4894', 'vert': '3000'}
# on 362 out of, 453
# {'name': 'Elk Mountain, Utah', 'lat': '38.32056', 'lng': '112.3916'}
# on 363 out of, 453
# {'name': 'Nordic Valley, Utah', 'lat': '41.300', 'lng': '111.8583\\x'}
# on 364 out of, 453
# {'name': 'Park City Mountain Resort', 'lat': '40.65083', 'lng': '111.5075'}
# on 365 out of, 453
# {'name': 'Powder Mountain', 'lat': '41.38000', 'lng': '111.7802', 'vert': '2205'}
# on 366 out of, 453
# {'name': 'Snowbasin', 'lat': '41.216', 'lng': '111.857\\xc', 'vert': '2959'}
# on 367 out of, 453
# {'name': 'Snowbird, Utah', 'lat': '40.58111', 'lng': '111.6563', 'vert': '3240'}
# on 368 out of, 453
# {'name': 'Solitude Mountain Resort', 'lat': '40.615139', 'lng': '111.588', 'vert': '2494'}
# on 369 out of, 453
# {'name': 'Sundance Resort', 'lat': '40.392', 'lng': '111.579\\xc', 'vert': '2150'}
# on 370 out of, 453
# {'name': 'Shell, Wyoming', 'lat': '44.53556', 'lng': '107.7791'}
# on 371 out of, 453
# {'name': 'Shell, Wyoming', 'lat': '44.53556', 'lng': '107.7791'}
# on 372 out of, 453
# {'name': 'Grand Targhee Resort', 'lat': '43.789', 'lng': '110.957\\xc', 'vert': '2454'}
# on 373 out of, 453
# {'name': 'Hogadon Ski Area', 'lat': '42.7449611', 'lng': '106.33'}
# on 374 out of, 453
# {'name': 'Jackson Hole Mountain Resort', 'lat': '43.59', 'lng': '110.89\\xc2\\'}
# on 375 out of, 453
# {'name': 'Ten Sleep, Wyoming', 'lat': '44.03472', 'lng': '107.4480'}
# on 376 out of, 453
# {'name': 'Pine Creek Ski Area', 'lat': '42.1031083', 'lng': '110.82'}
# on 377 out of, 453
# {'name': 'Cody, Wyoming', 'lat': '44.52333', 'lng': '109.0572'}
# on 378 out of, 453
# {'name': 'Cody, Wyoming', 'lat': '44.52333', 'lng': '109.0572'}
# on 379 out of, 453
# {'name': 'Snowy Range Ski Area', 'lat': '41.341231', 'lng': '106.183'}
# on 380 out of, 453
# {'name': 'White Pine Ski Resort', 'lat': '42.9778389', 'lng': '109.75'}
# on 381 out of, 453
# {'name': 'Arctic Valley Ski Area', 'lat': '61.24667', 'lng': '149.6505', 'vert': '1500'}
# on 382 out of, 453
# {'name': 'Alyeska Resort', 'lat': '60.9705', 'lng': '149.0982\\', 'vert': '2500'}
# on 383 out of, 453
# {'name': 'Eaglecrest Ski Area', 'lat': '58.27611', 'lng': '134.5152', 'vert': '1620'}
# on 384 out of, 453
# {'name': 'Hilltop Ski Area', 'lat': '61.14083', 'lng': '149.7450', 'vert': '294'}
# on 385 out of, 453
# {'name': 'Hilltop Ski Area', 'lat': '61.14083', 'lng': '149.7450', 'vert': '294'}
# on 386 out of, 453
# {'name': 'Moose Mountain (Alaska)', 'lat': '64.94056', 'lng': '147.9905'}
# on 387 out of, 453
# {'name': 'Mount Eyak', 'lat': '60.55000', 'lng': '145.7500', 'vert': '849'}
# on 388 out of, 453
# {'name': 'Skiland', 'lat': '65.04889', 'lng': '147.4091', 'vert': '1027'}
# on 389 out of, 453
# {'name': 'Alpine Meadows (ski resort)', 'lat': '39.164', 'lng': '120.239\\xc', 'vert': '1802'}
# on 390 out of, 453
# {'name': 'Alpine Meadows (ski resort)', 'lat': '39.164', 'lng': '120.239\\xc', 'vert': '1802'}
# on 391 out of, 453
# {'name': 'Badger Pass Ski Area', 'lat': '37.66194', 'lng': '119.6636', 'vert': '800'}
# on 392 out of, 453
# {'name': 'Bear Mountain (ski area)', 'lat': '34.2267', 'lng': '116.8602\\', 'vert': '1665'}
# on 393 out of, 453
# {'name': 'Bear Valley (resort)', 'lat': '38.492', 'lng': '120.044\\xc', 'vert': '1900'}
# on 394 out of, 453
# {'name': 'Boreal Mountain Resort', 'lat': '39.3317', 'lng': '120.3511\\'}
# on 395 out of, 453
# {'name': 'Buckhorn Ski Club', 'lat': '34.34457', 'lng': '117.9143', 'vert': '680'}
# on 396 out of, 453
# {'name': 'China Peak', 'lat': '37.2297', 'lng': '119.1583\\'}
# on 397 out of, 453
# {'name': 'Dodge Ridge Ski Area', 'lat': '38.1896', 'lng': '119.9564\\', 'vert': '1600'}
# on 398 out of, 453
# {'name': 'Donner Ski Ranch', 'lat': '39.3183139', 'lng': '120.33', 'vert': '750'}
# on 399 out of, 453
# {'name': 'Granlibakken', 'lat': '39.1556', 'lng': '120.1551\\'}
# on 400 out of, 453
# {'name': 'Heavenly Mountain Resort', 'lat': '38.9353', 'lng': '119.9400\\', 'vert': '3812'}
# on 401 out of, 453
# {'name': 'Homewood Mountain Resort', 'lat': '39.0827', 'lng': '120.1755\\', 'vert': '503'}
# on 402 out of, 453
# {'name': 'June Mountain ski area', 'lat': '37.7683', 'lng': '119.0906\\', 'vert': '2545'}
# on 403 out of, 453
# {'name': 'Kirkwood Mountain Resort', 'lat': '38.684', 'lng': '120.068\\xc', 'vert': '2000'}
# on 404 out of, 453
# {'name': 'Mammoth Mountain Ski Area', 'lat': '37.63056', 'lng': '119.0325', 'vert': '3100'}
# on 405 out of, 453
# {'name': 'Mount Baldy Ski Lifts', 'lat': '34.27', 'lng': '117.62\\xc2\\', 'vert': '2100'}
# on 406 out of, 453
# {'name': 'Mount Baldy Ski Lifts', 'lat': '34.27', 'lng': '117.62\\xc2\\', 'vert': '2100'}
# on 407 out of, 453
# {'name': 'Mount Waterman', 'lat': '34.349722', 'lng': '117.928', 'vert': '1030'}
# on 408 out of, 453
# {'name': 'Mountain High', 'lat': '34.37472', 'lng': '117.6932', 'vert': '1600'}
# on 409 out of, 453
# {'name': 'Northstar California', 'lat': '39.264', 'lng': '120.125\\xc', 'vert': '2280'}
# on 410 out of, 453
# {'name': 'Sierra-at-Tahoe', 'lat': '38.8002', 'lng': '120.0806\\', 'vert': '2212'}
# on 411 out of, 453
# {'name': 'Snow Summit', 'lat': '34.2286', 'lng': '116.8911\\', 'vert': '1209'}
# on 412 out of, 453
# {'name': 'Snow Valley Mountain Resort', 'lat': '34.223375', 'lng': '117.037', 'vert': '1041'}
# on 413 out of, 453
# {'name': 'Snow Valley Mountain Resort', 'lat': '34.223375', 'lng': '117.037', 'vert': '1041'}
# on 414 out of, 453
# {'name': 'Squaw Valley Ski Resort', 'lat': '39.196', 'lng': '120.235\\xc', 'vert': '2850'}
# on 415 out of, 453
# {'name': 'Sugar Bowl Ski Resort', 'lat': '39.30444', 'lng': '120.3358'}
# on 416 out of, 453
# {'name': 'Tahoe Donner Downhill', 'lat': '39.3549', 'lng': '120.2590\\', 'vert': '600'}
# on 417 out of, 453
# {'name': 'Diamond Peak (ski area)', 'lat': '39.254', 'lng': '119.924\\xc', 'vert': '1840'}
# on 418 out of, 453
# {'name': 'Lee Canyon (Ski and Snowboard Resort)', 'lat': '36.301638', 'lng': '115.680'}
# on 419 out of, 453
# {'name': 'Mount Rose Ski Tahoe', 'lat': '39.32917', 'lng': '119.8858', 'vert': '1800'}
# on 420 out of, 453
# {'name': 'Mount Rose Ski Tahoe', 'lat': '39.32917', 'lng': '119.8858', 'vert': '1800'}
# on 421 out of, 453
# {'name': 'Mount Rose Ski Tahoe', 'lat': '39.32917', 'lng': '119.8858', 'vert': '1800'}
# on 422 out of, 453
# {'name': 'Anthony Lakes (ski area)', 'lat': '44.9637', 'lng': '118.2348\\', 'vert': '900'}
# on 423 out of, 453
# {'name': 'Cooper Spur ski area', 'lat': '45.41228', 'lng': '121.6050'}
# on 424 out of, 453
# {'name': 'Ferguson Ridge Ski Area', 'lat': '45.28209', 'lng': '117.1128'}
# on 425 out of, 453
# {'name': 'Hoodoo (ski area)', 'lat': '44.409', 'lng': '121.872\\xc', 'vert': '1035'}
# on 426 out of, 453
# {'name': 'Mount Ashland Ski Area', 'lat': '42.08333', 'lng': '122.7166'}
# on 427 out of, 453
# {'name': 'Mount Bachelor ski area', 'lat': '44.003', 'lng': '121.677\\xc', 'vert': '3365'}
# on 428 out of, 453
# {'name': 'Mount Hood Meadows', 'lat': '45.32889', 'lng': '121.6625'}
# on 429 out of, 453
# {'name': 'Mount Hood Skibowl', 'lat': '45.30189', 'lng': '121.7732'}
# on 430 out of, 453
# {'name': 'Spout Springs Ski Area', 'lat': '45.7550', 'lng': '118.0543\\', 'vert': '530'}
# on 431 out of, 453
# {'name': 'Summit Ski Area', 'lat': '45.303000', 'lng': '121.747'}
# on 432 out of, 453
# {'name': 'Timberline Lodge ski area', 'lat': '45.33', 'lng': '121.71\\xc2\\', 'vert': '3620'}
# on 433 out of, 453
# {'name': 'Warner Canyon', 'lat': '42.23749', 'lng': '120.2958'}
# on 434 out of, 453
# {'name': 'Willamette Pass Resort', 'lat': '43.60', 'lng': '122.036\\xc2', 'vert': '1563'}
# on 435 out of, 453
# {'name': '49 Degrees North Ski Area', 'lat': '48.301', 'lng': '117.563\\xc', 'vert': '1851'}
# on 436 out of, 453
# {'name': 'Badger Mountain Ski Area', 'lat': '47.61273', 'lng': '120.1297'}
# on 437 out of, 453
# {'name': 'Crystal Mountain (Washington)', 'lat': '46.93', 'lng': '121.48\\xc2\\', 'vert': '3100'}
# on 438 out of, 453
# {'name': 'Echo Valley Ski Area', 'lat': '47.93583', 'lng': '120.0561'}
# on 439 out of, 453
# {'name': 'Hurricane Ridge Ski and Snowboard Area', 'lat': '47.971', 'lng': '123.493\\xc'}
# on 440 out of, 453
# {'name': 'Leavenworth Ski Hill', 'lat': '47.61437', 'lng': '120.6685'}
# on 441 out of, 453
# {'name': 'Loup Loup Ski Bowl', 'lat': '48.39472', 'lng': '119.9127'}
# on 442 out of, 453
# {'name': 'Meany Lodge', 'lat': '47.28028', 'lng': '121.3205', 'vert': '440'}
# on 443 out of, 453
# {'name': 'Mission Ridge Ski Area', 'lat': '47.292', 'lng': '120.399\\xc', 'vert': '2250'}
# on 444 out of, 453
# {'name': 'Mt. Baker Ski Area', 'lat': '48.862', 'lng': '121.654\\xc', 'vert': '1589'}
# on 445 out of, 453
# {'name': 'Mount Spokane Ski and Snowboard Park', 'lat': '47.922', 'lng': '117.097\\xc', 'vert': '2071'}
# on 446 out of, 453
# {'name': 'Mount Spokane Ski and Snowboard Park', 'lat': '47.922', 'lng': '117.097\\xc', 'vert': '2071'}
# on 447 out of, 453
# {'name': 'Mount Spokane Ski and Snowboard Park', 'lat': '47.922', 'lng': '117.097\\xc', 'vert': '2071'}
# on 448 out of, 453
# {'name': 'Ski Bluewood', 'lat': '46.082', 'lng': '117.851\\xc', 'vert': '1125'}
# on 449 out of, 453
# {'name': 'Stevens Pass Ski Area', 'lat': '47.74472', 'lng': '121.0888', 'vert': '1800'}
# on 450 out of, 453
# {'name': 'The Summit at Snoqualmie', 'lat': '47.424', 'lng': '121.416\\xc', 'vert': '2280'}
# on 451 out of, 453
# {'name': 'Alpental', 'lat': '47.44306', 'lng': '121.4294'}
# on 452 out of, 453
# {'name': 'White Pass Ski Area', 'lat': '46.63528', 'lng': '121.3875', 'vert': '2000'}

# %%
for area in ski_areas_formatted:
    while (not str.isdigit(area['lng'][len(area['lng'])-1])) or area['lng'][-2:] == 'c2':
        area['lng'] = area['lng'][:-1]
    area['lng'] = -float(area['lng'])

# %%
skiarea_csv = []
num = 0
for area in ski_areas_formatted:
    if 'vert' in area:
        skiarea_csv.append([area['name'], area['lat'], area['lng'], area['vert']])
    else:
        skiarea_csv.append([area['name'], area['lat'], area['lng']])
    print(skiarea_csv[num])
    num += 1
# Out:
# ['Mohawk Mountain Ski Area', '41.83675', -73.31342, '650']
# ['Mount Southington', '41.58235', -72.92587, '425']
# ['Powder Ridge Ski Area', '41.502006', -72.7371, '550']
# ['Ski Sundown', '41.88407', -72.94523, '625']
# ['Baker Mountain (ski area)', '45.08472', -69.90556]
# ['Big Rock (ski resort)', '46.52222', -67.82778]
# ['Big Squaw Mountain Resort', '45.50417', -69.70556]
# ['Black Mountain of Maine', '44.58000', -70.6175, '1380']
# ['Camden Snow Bowl', '44.217216', -69.1346, '845']
# ['Eaton Mountain', '44.76806', -69.61944]
# ['Lonesome Pine Trails', '47.23278', -68.59306]
# ['Lost Valley Ski Area', '44.136', -70.281, '240']
# ['Ski Mount Abram', '44.37917', -70.70694]
# ['Powderhouse Hill (ski area)', '43.23694', -70.80222]
# ['Saddleback Maine (ski resort)', '44.93667', -70.50306, '2000']
# ['Shawnee Peak Ski Area', '44.05833', -70.81528, '1300']
# ['Sugarloaf (ski resort)', '45.03139', -70.31306, '2820']
# ['Sunday River (ski resort)', '44.46944', -70.86111]
# ['Titcomb Mountain', '44.65000', -70.17083]
# ['Berkshire East Ski Resort', '42.62083', -72.87694]
# ['Blandford Ski Area', '42.18885139', -72.9, '465']
# ['Blue Hills Ski Area', '42.21528', -71.11917, '309']
# ['Ski Butternut', '42.17806', -73.31694, '1000']
# ['Easton Ski Area', '42.5387', -72.5938]
# ['Jiminy Peak (ski area)', '42.55083', -73.29083, '1150']
# ['Nashoba Valley Ski Area', '42.5419750', -71.444, '240']
# ['Otis Ridge', '42.1964', -73.0988, '400']
# ['Ski Bradford', '42.74361', -71.05889]
# ['Ski Ward', '42.30556', -71.675, '220']
# ['Wachusett Mountain (ski area)', '42.49944', -71.88639, '1006']
# ['Arrowhead Recreation Area', '43.36278', -72.33333]
# ['Attitash Mountain Resort', '44.08222', -71.22972, '1750']
# ['Black Mountain Ski Area (New Hampshire)', '44.16833', -71.16444, '1100']
# ['Bretton Woods Mountain Resort', '44.25972', -71.46222, '1500']
# ['Cannon Mountain Ski Area', '44.15778', -71.69889, '2330']
# ['Cranmore Mountain Resort', '44.05639', -71.11, '1200']
# ['Crotched Mountain', '42.998294108', -71.8]
# ['Dartmouth Skiway', '43.78667', -72.43389]
# ['Granite Gorge Ski Area', '42.97083', -72.21222, '390']
# ['Gunstock Mountain Resort', '43.54139', -71.3675, '1400']
# ['King Pine', '43.87139', -71.08944, '350']
# ['Loon Mountain', '44.03597', -71.62144]
# ['McIntyre Ski Area', '43.00500', -71.44, '180']
# ['Mount Sunapee Resort', '43.33056', -72.08, '1513']
# ['Pats Peak', '43.16333', -71.79583, '770']
# ['Ragged Mountain Resort', '43.48444', -71.84222, '1250']
# ['Tenney Mountain Ski Resort', '43.73778', -71.78361, '1400']
# ['The Balsams Grand Resort Hotel', '44.87056', -71.30778]
# ['Waterville Valley Resort', '43.96528', -71.52778, '2020']
# ['Whaleback (ski area)', '43.60139', -72.18139, '700']
# ['Wildcat Mountain Ski Area', '44.26306', -71.23833, '2112']
# ['Yawgoo Valley', '41.51694', -71.52944]
# ['Brownsville, Vermont', '43.46861', -72.47083]
# ['Bolton Valley', '44.419621', -72.8499, '1625']
# ['Bromley Mountain', '43.22778', -72.93861, '1334']
# ['Burke Mountain (Vermont)', '44.57083', -71.89317]
# ['Skiing Cochrans', '44.396', -72.982]
# ['Jay Peak Resort', '44.92944', -72.53222, '2153']
# ['Killington Ski Resort', '43.626', -72.798, '3050']
# ['Mad River Glen', '44.20083', -72.92444, '2000']
# ['Magic Mountain Ski Area', '43.19278', -72.76, '1500']
# ['Middlebury College Snow Bowl', '43.94', -72.96]
# ['Mount Snow', '42.959835', -72.9221]
# ['Northeast Slopes', '44.07250', -72.25028, '340']
# ['Okemo Mountain', '43.40139', -72.71667, '2200']
# ['Pico Mountain', '43.66167', -72.8425, '1967']
# ['Plymouth Notch, Vermont', '43.5299', -72.7388]
# ['Quechee Ski Area', '43.6572', -72.4431]
# ["Smugglers' Notch Resort", '44.57278', -72.77611, '2610']
# ['Stowe Mountain Resort', '44.53194', -72.7875, '2360']
# ['Stratton Mountain Resort', '43.11417', -72.90667, '2003']
# ['Sugarbush Resort', '44.135098', -72.8859, '2600']
# ['Suicide Six', '43.66389', -72.54444, '650']
# ['Wisp Ski Resort', '39.55806', -79.36306, '700']
# ['Big Snow American Dream', '40.81111', -74.07]
# ['Campgaw Mountain', '41.0542633', -74.199]
# ['Hidden Valley (New Jersey)', '41.1856000', -74.48, '620']
# ['Mountain Creek', '41.181', -74.513]
# ['Belleayre Mountain', '42.1422139', -74.51]
# ['Bristol Mountain Ski Resort', '42.745', -77.404444, '1150']
# ['Catamount Ski Area', '42.171457', -73.4777, '1000']
# ['Gore Mountain (ski resort)', '43.67222', -74.00694, '2537']
# ['Greek Peak Mountain Resort', '42.5085996', -76.146]
# ['Holiday Valley (ski resort)', '42.26250', -78.66806, '750']
# ['Hunter Mountain (ski area)', '42.200278', -74.2302, '1600']
# ['McCauley Mountain (New York)', '43.6925676', -74.961]
# ["Peek'n Peak", '42.06250', -79.73667, '400']
# ['Plattekill Mountain', '42.290251', -74.6536, '1100']
# ['Thunder Ridge Ski Area', '41.50722', -73.58111, '403']
# ['Titus Mountain', '44.76333', -74.23528]
# ['West Mountain (ski area)', '43.28556', -73.72833, '1010']
# ['Whiteface Mountain', '44.36583', -73.90278]
# ['Windham Mountain', '42.29167', -74.25944, '1600']
# ['Bear Creek Ski and Recreation Area', '40.47611', -75.62583]
# ['Blue Mountain Resort', '40.82222', -75.51333, '1082']
# ['Boyce Park', '40.46556', -79.74528]
# ['Camelback Mountain Resort', '41.05139', -75.35528, '800']
# ['Elk Mountain Ski Area', '41.721', -75.559, '925']
# ['Hidden Valley Resort (Pennsylvania)', '40.058042', -79.2582, '470']
# ['Jack Frost Ski Resort', '41.111', -75.652]
# ['Liberty Mountain Resort', '39.763500', -77.375, '620']
# ['Mount Pleasant of Edinboro', '41.85111', -80.07028, '350']
# ['Seven Springs Mountain Resort', '40.02306', -79.29278, '750']
# ['Shawnee Mountain Ski Area', '41.04083', -75.08333, '700']
# ['Ski Big Bear', '41.52333', -75.025]
# ['Roundtop Mountain Resort', '40.108', -76.926, '600']
# ['Montage Mountain Ski Resort', '41.3533', -75.6592, '1000']
# ['Tussey Mountain Ski Area', '40.7682', -77.752, '500']
# ['Whitetail Ski Resort', '39.74167', -77.93278, '935']
# ['Appalachian Ski Mountain', '36.174', -81.662]
# ['Cataloochee Ski Area', '35.563', -83.09]
# ['Wolf Ridge Ski Resort', '35.955', -82.509]
# ['Ober Gatlinburg', '35.708969', -83.5215]
# ['Bryce Resort', '38.81750', -78.76583, '500']
# ['Massanutten Mountain', '38.643028', -78.612]
# ['The Omni Homestead Resort', '37.9954722', -79.829]
# ['Wintergreen Resort', '37.93000', -78.94167, '1003']
# ['Canaan Valley Resort State Park', '39.02361', -79.46583]
# ['Snowshoe Mountain', '38.40889', -79.99472, '1500']
# ['Winterplace Ski Resort', '37.59000', -81.115, '603']
# ['Ski Snowstar', '41.4250', -90.7438]
# ['Paoli Peaks', '38.55778', -86.51028, '300']
# ['Perfect North Slopes', '39.149208', -84.8865, '400']
# ['Big Powderhorn Mountain', '46.50417', -90.09611]
# ['Blackjack Ski Resort (Bessemer, Michigan)', '46.5021', -90.0046, '490']
# ['Boyne Highlands', '45.47083', -84.93472, '552']
# ['Boyne Mountain Resort', '45.16389', -84.93278]
# ['Caberfae Peaks Ski &amp; Golf Resort', '44.24972', -85.725, '485']
# ['Crystal Mountain (Michigan)', '44.52000', -85.99222, '375']
# ['Indianhead Mountain', '46.50000', -89.97083, '520']
# ['Marquette Mountain', '46.508', -87.42]
# ['Mont Ripley', '47.12917', -88.55944]
# ['Mount Bohemia', '47.39167', -88.01361, '900']
# ['Mount Brighton', '42.53806', -83.80694]
# ["Mulligan's Hollow Ski Bowl", '43.0564', -86.2393]
# ["Nub's Nob", '45.47', -84.903]
# ['Pine Knob', '42.7422524', -83.367]
# ['Porcupine Mountains', '46.78111', -89.68083]
# ['Ski Brule', '46.028', -88.701]
# ['Timber Ridge Ski Area', '42.391711', -85.779]
# ['Afton Alps', '44.85556', -92.78917, '350']
# ['Buck Hill', '44.724', -93.283]
# ['Buena Vista Ski Area', '47.65806', -94.87917]
# ['Hyland Hills Ski Area', '44.844', -93.364]
# ['Lutsen Mountains', '47.664', -90.714, '825']
# ['Mount Kato', '44.13139', -94.03639, '240']
# ['Spirit Mountain (ski area)', '46.71944', -92.21806, '678']
# ['Welch Village', '44.56056', -92.72722]
# ['Wild Mountain', '45.48889', -92.70556]
# ['Hidden Valley Ski Area', '38.535578', -90.6528, '320']
# ['Snow Creek (ski resort)', '39.468651', -94.9719, '300']
# ['Bottineau Winter Park', '48.951', -100.473]
# ['Frost Fire Park', '48.912', -98.068]
# ['Huff Hills', '46.62694', -100.7233]
# ['Alpine Valley Ski Area', '41.5303', -81.2662, '230']
# ['Boston Mills/Brandywine Ski Resort', '41.26417', -81.565, '240']
# ['Mad River Mountain', '40.3163167', -83.68]
# ['Mystic Miner Ski Resort', '44.3084333', -103.81, '699']
# ['Great Bear Recreation Park', '43.5821000', -96.664, '178']
# ['Terry Peak', '44.329', -103.835, '1164']
# ['Alpine Valley Resort (Wisconsin)', '42.736', -88.428]
# ['Cascade Mountain (ski area)', '43.5039278', -89.518, '450']
# ["Devil's Head Resort", '43.42306', -89.62694, '500']
# ['Granite Peak Ski Area', '44.92861', -89.6825, '700']
# ['Kettlebowl', '45.271323000', -88.9]
# ['Telemark Lodge', '46.190056', -91.2476]
# ['Trollhaugen', '45.35125', -92.61801]
# ['Tyrol Basin', '43.042647', -89.7777, '260']
# ['Wilmot Mountain', '42.50000', -88.18889, '190']
# ['Arizona Snowbowl', '35.330', -111.705]
# ['Elk Ridge Ski Area', '35.21056', -112.1925]
# ['Mount Lemmon Ski Valley', '32.45222', -110.7838]
# ['Sunrise Park Resort', '33.97333', -109.5647, '1900']
# ['Arapahoe Basin', '39.64167', -105.8716]
# ['Aspen Highlands', '39.18111', -106.8563, '3638']
# ['Aspen Mountain (ski area)', '39.18639', -106.8186]
# ['Buttermilk (ski area)', '39.20500', -106.8605, '2030']
# ['Snowmass (ski area)', '39.1956', -106.9513, '4406']
# ['Beaver Creek Resort', '39.63139', -106.5216, '3340']
# ['Breckenridge Ski Resort', '39.480', -106.067]
# ['Copper Mountain (Colorado)', '39.50167', -106.1563]
# ['Crested Butte Mountain Resort', '38.89972', -106.965]
# ['Echo Mountain Resort', '39.68500', -105.5194, '600']
# ['Eldora Mountain Resort', '39.93750', -105.5836, '1240']
# ['Hesperus Ski Area', '37.29778', -108.055]
# ['Howelsen Hill Ski Area', '40.483', -106.839]
# ['Kendall Mountain Ski Area', '37.81135', -107.6565]
# ['Keystone Resort', '39.60500', -105.9541]
# ['Loveland Ski Area', '39.680', -105.897]
# ['Monarch Ski Area', '38.51250', -106.3325]
# ['Powderhorn Resort', '39.06306', -108.1555, '1650']
# ['Purgatory Resort', '37.62972', -107.8144, '2029']
# ['Silverton Mountain', '37.88470', -107.6652]
# ['Ski Cooper', '39.360', -106.302, '1200']
# ['Steamboat Ski Resort', '40.459', -106.803]
# ['Sunlight Ski Area', '39.399806', -107.339, '2010']
# ['Telluride Ski Resort', '37.93639', -107.8202, '4425']
# ['Vail Ski Resort', '39.639', -106.374]
# ['Winter Park Resort', '39.88694', -105.7625]
# ['Wolf Creek ski area', '37.47222', -106.7933]
# ['Bald Mountain Ski Area', '46.57', -115.87]
# ['Bogus Basin', '43.764', -116.104, '1790']
# ['Brundage Mountain', '45.005', -116.155, '1800']
# ['Cottonwood Butte', '46.0755', -116.4528]
# ['Kelly Canyon', '43.64583', -111.63, '1000']
# ['Little Ski Hill', '44.93000', -116.163]
# ['Lookout Pass Ski and Recreation Area', '47.453', -115.707, '1150']
# ['Lost Trail Powder Mountain', '45.692', -113.952, '1800']
# ['Magic Mountain Resort', '42.188306', -114.286]
# ['Pebble Creek, Idaho', '42.778', -112.16, '2911']
# ['Sandpoint, Idaho', '48.267', -116.567]
# ['Pomerelle', '42.318', -113.608, '1002']
# ['Rotarun Ski Area', '43.497500', -114.366, '475']
# ['Schweitzer Mountain', '48.367', -116.623, '2440']
# ['Silver Mountain (Idaho)', '47.495', -116.135, '2197']
# ['Snowhaven', '45.869000', -116.09]
# ['Soldier Mountain', '43.485', -114.83, '1425']
# ['Bald Mountain (Idaho)', '43.65500', -114.4091, '3400']
# ['Tamarack Resort', '44.671', -116.123, '2760']
# ['Havre, Montana', '48.550', -109.683]
# ['Big Sky Resort', '45.25000', -111.4166, '4350']
# ['Blacktail Mountain Ski Area', '48.01306', -114.2469]
# ['Bridger Bowl Ski Area', '45.818', -110.897, '2600']
# ['Discovery Ski Area', '46.25639', -113.2419]
# ['Great Divide Montana', '46.7497', -112.3043]
# ['Lost Trail Powder Mountain', '45.692', -113.952, '1800']
# ['Maverick Mountain Ski Area', '45.43500', -113.1294]
# ['Montana Snowbowl', '47.02', -114.0, '2600']
# ['Moonlight Basin', '45.31417', -111.4508]
# ['Red Lodge Mountain', '45.191', -109.335, '2400']
# ['Showdown Ski Area', '46.83861', -110.7088]
# ['Teton Pass Ski Area', '47.92806', -112.8152]
# ['Turner Mountain Ski Resort', '48.605', -115.63, '2110']
# ['Whitefish Mountain Resort', '48.50', -114.34, '2353']
# ['Yellowstone Club', '45.2313833', -111.45]
# ['Angel Fire Resort', '36.38750', -105.2733]
# ['Pajarito Mountain Ski Area', '35.89417', -106.3902]
# ['Sandia Peak Tramway', '35.19056', -106.4794]
# ['Sipapu Ski &amp; Summer Resort', '36.154211', -105.548, '1055']
# ['Ski Apache', '33.39722', -105.7991, '1900']
# ['Ski Cloudcroft', '32.9507083', -105.7]
# ['Ski Santa Fe', '35.7963250', -105.8]
# ['Taos Ski Valley, New Mexico', '36.59778', -105.445]
# ['Alta Ski Area', '40.58083', -111.6372, '2538']
# ['Beaver Mountain', '41.968', -111.541, '1600']
# ['Brian Head Ski Resort', '37.683', -112.833, '1707']
# ['Brighton Ski Resort', '40.60000', -111.5833, '1750']
# ['Cherry Peak Resort', '41.92639', -111.7566, '1265']
# ['Deer Valley', '40.62278', -111.4894, '3000']
# ['Elk Mountain, Utah', '38.32056', -112.3916]
# ['Nordic Valley, Utah', '41.300', -111.8583]
# ['Park City Mountain Resort', '40.65083', -111.5075]
# ['Powder Mountain', '41.38000', -111.7802, '2205']
# ['Snowbasin', '41.216', -111.857, '2959']
# ['Snowbird, Utah', '40.58111', -111.6563, '3240']
# ['Solitude Mountain Resort', '40.615139', -111.588, '2494']
# ['Sundance Resort', '40.392', -111.579, '2150']
# ['Shell, Wyoming', '44.53556', -107.7791]
# ['Grand Targhee Resort', '43.789', -110.957, '2454']
# ['Hogadon Ski Area', '42.7449611', -106.33]
# ['Jackson Hole Mountain Resort', '43.59', -110.89]
# ['Ten Sleep, Wyoming', '44.03472', -107.448]
# ['Pine Creek Ski Area', '42.1031083', -110.82]
# ['Cody, Wyoming', '44.52333', -109.0572]
# ['Snowy Range Ski Area', '41.341231', -106.183]
# ['White Pine Ski Resort', '42.9778389', -109.75]
# ['Arctic Valley Ski Area', '61.24667', -149.6505, '1500']
# ['Alyeska Resort', '60.9705', -149.0982, '2500']
# ['Eaglecrest Ski Area', '58.27611', -134.5152, '1620']
# ['Hilltop Ski Area', '61.14083', -149.745, '294']
# ['Moose Mountain (Alaska)', '64.94056', -147.9905]
# ['Mount Eyak', '60.55000', -145.75, '849']
# ['Skiland', '65.04889', -147.4091, '1027']
# ['Alpine Meadows (ski resort)', '39.164', -120.239, '1802']
# ['Badger Pass Ski Area', '37.66194', -119.6636, '800']
# ['Bear Mountain (ski area)', '34.2267', -116.8602, '1665']
# ['Bear Valley (resort)', '38.492', -120.044, '1900']
# ['Boreal Mountain Resort', '39.3317', -120.3511]
# ['Buckhorn Ski Club', '34.34457', -117.9143, '680']
# ['China Peak', '37.2297', -119.1583]
# ['Dodge Ridge Ski Area', '38.1896', -119.9564, '1600']
# ['Donner Ski Ranch', '39.3183139', -120.33, '750']
# ['Granlibakken', '39.1556', -120.1551]
# ['Heavenly Mountain Resort', '38.9353', -119.94, '3812']
# ['Homewood Mountain Resort', '39.0827', -120.1755, '503']
# ['June Mountain ski area', '37.7683', -119.0906, '2545']
# ['Kirkwood Mountain Resort', '38.684', -120.068, '2000']
# ['Mammoth Mountain Ski Area', '37.63056', -119.0325, '3100']
# ['Mount Baldy Ski Lifts', '34.27', -117.62, '2100']
# ['Mount Waterman', '34.349722', -117.928, '1030']
# ['Mountain High', '34.37472', -117.6932, '1600']
# ['Northstar California', '39.264', -120.125, '2280']
# ['Sierra-at-Tahoe', '38.8002', -120.0806, '2212']
# ['Snow Summit', '34.2286', -116.8911, '1209']
# ['Snow Valley Mountain Resort', '34.223375', -117.037, '1041']
# ['Squaw Valley Ski Resort', '39.196', -120.235, '2850']
# ['Sugar Bowl Ski Resort', '39.30444', -120.3358]
# ['Tahoe Donner Downhill', '39.3549', -120.259, '600']
# ['Diamond Peak (ski area)', '39.254', -119.924, '1840']
# ['Lee Canyon (Ski and Snowboard Resort)', '36.301638', -115.68]
# ['Mount Rose Ski Tahoe', '39.32917', -119.8858, '1800']
# ['Anthony Lakes (ski area)', '44.9637', -118.2348, '900']
# ['Cooper Spur ski area', '45.41228', -121.605]
# ['Ferguson Ridge Ski Area', '45.28209', -117.1128]
# ['Hoodoo (ski area)', '44.409', -121.872, '1035']
# ['Mount Ashland Ski Area', '42.08333', -122.7166]
# ['Mount Bachelor ski area', '44.003', -121.677, '3365']
# ['Mount Hood Meadows', '45.32889', -121.6625]
# ['Mount Hood Skibowl', '45.30189', -121.7732]
# ['Spout Springs Ski Area', '45.7550', -118.0543, '530']
# ['Summit Ski Area', '45.303000', -121.747]
# ['Timberline Lodge ski area', '45.33', -121.71, '3620']
# ['Warner Canyon', '42.23749', -120.2958]
# ['Willamette Pass Resort', '43.60', -122.036, '1563']
# ['49 Degrees North Ski Area', '48.301', -117.563, '1851']
# ['Badger Mountain Ski Area', '47.61273', -120.1297]
# ['Crystal Mountain (Washington)', '46.93', -121.48, '3100']
# ['Echo Valley Ski Area', '47.93583', -120.0561]
# ['Hurricane Ridge Ski and Snowboard Area', '47.971', -123.493]
# ['Leavenworth Ski Hill', '47.61437', -120.6685]
# ['Loup Loup Ski Bowl', '48.39472', -119.9127]
# ['Meany Lodge', '47.28028', -121.3205, '440']
# ['Mission Ridge Ski Area', '47.292', -120.399, '2250']
# ['Mt. Baker Ski Area', '48.862', -121.654, '1589']
# ['Mount Spokane Ski and Snowboard Park', '47.922', -117.097, '2071']
# ['Ski Bluewood', '46.082', -117.851, '1125']
# ['Stevens Pass Ski Area', '47.74472', -121.0888, '1800']
# ['The Summit at Snoqualmie', '47.424', -121.416, '2280']
# ['Alpental', '47.44306', -121.4294]
# ['White Pass Ski Area', '46.63528', -121.3875, '2000']

# %%
fields = ['name', 'lat', 'lng', 'vert']
with open('skiareas_sorted_vert.csv', 'w') as f: 
      
    # using csv.writer method from CSV package 
    write = csv.writer(f) 
      
    write.writerow(fields) 
    write.writerows(skiarea_csv)

# %%
cityjsonsorted = []
citynum = 0
for city in cityjson:
    cityjsonsorted.append([])
    cityjsonsorted[citynum].append(city['city'])
    cityjsonsorted[citynum].append(city['growth_from_2000_to_2013'])
    cityjsonsorted[citynum].append(city['latitude'])
    cityjsonsorted[citynum].append(city['longitude'])
    cityjsonsorted[citynum].append(city['population'])
    cityjsonsorted[citynum].append(city['rank'])
    cityjsonsorted[citynum].append(city['state'])
    citynum += 1

# %%
new_fields = ['city_name', 'growth_2000_2013', 'lat', 'lng', 'pop', 'rank_size', 'state']
with open('cities_sorted.csv', 'w') as f:
    write = csv.writer(f)
    write.writerow(new_fields)
    write.writerows(cityjsonsorted)

# %%
features = []
for area in ski_areas_formatted:
    latitude, longitude = map(float, (area['lat'], area['lng']))
    if 'vert' in area:
        features.append(
            Feature(
                geometry = Point((longitude, latitude)),
                properties = {
                    'name': area['name'],
                    'vertical': area['vert']
                }
            )
        )
    else:
        features.append(
            Feature(
                geometry = Point((longitude, latitude)),
                properties = {
                    'name': area['name']
                }
            )
        )

collection = FeatureCollection(features)
with open("ski_geojson.json", "w") as f:
    f.write('%s' % collection)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-6ea99c80714b> in <module>
#       7             properties = {
#       8                 'name': area['name'],
# ----> 9                 'vertical': area['vert']
#      10             }
#      11         )
#
# KeyError: 'vert'
